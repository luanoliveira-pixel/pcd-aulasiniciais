# %% [markdown]
# <a href="https://colab.research.google.com/github/luanoliveira-pixel/pcd-aulasiniciais/blob/main/Atividade1_12_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nota1 = 8
nota2 = 9
nota3 = 7

media = (nota1 + nota2 + nota3) / 3

print("Nota 1:", nota1)
print("Nota 2:", nota2)
print("Nota 3:", nota3)
print("Média:", media)
# Out:
# Nota 1: 8
# Nota 2: 9
# Nota 3: 7
# Média: 8.0
